# %%
# %matplotlib inline

import pandas
import matplotlib.pyplot as plt

f = open('data.txt', 'r')
experiments = []
for num in f:
    experiments.append(float(num))
#plt.plot(list(range(len(experiments))), experiments)
#plt.title('My DATA 3000')
#plt.show()

df = pandas.DataFrame(data={
    'experiments': experiments
})

df.to_csv("experiments.csv")

df1 = pandas.read_csv("experiments.csv")
df1['experiments'].plot()

# %%
df.plot.kde()

# %%
from scipy import stats
print(stats.kstest(df, 'norm', (df.mean(), df.std())))
# Out:
# KstestResult(statistic=0.9600634373649027, pvalue=0.0)
